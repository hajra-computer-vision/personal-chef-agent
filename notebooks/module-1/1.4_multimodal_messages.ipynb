# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model = "minimax-m3:cloud", temperature = 0)

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# What a wonderful question! Since the Moon has no official capital, I'll invent one for you with all the wonder and detail of a science fiction epic.
#
# # **Selenograd Prime** — The Capital of Luna
#
# Nestled within the silver-glass domes of **Mare Tranquillitatis**, where humanity first planted its flag a century ago, lies the gleaming metropolis of **Selenograd Prime** — the seat of the Lunar Coalition and the beating heart of the Sol system's first off-world civilization.
#
# ## 🌑 Geography
#
# The city sprawls across a colossal network of pressurized crater-domes connected by vacuum-tube maglev corridors. The original landing site of **Tranquility Base** has been preserved as a sacred heritage park, its dusty footprints encased in a shimmering time-stop field.
#
# ## 🏛️ Landmark: The Tidestone Parliament
#
# At the city's heart rises the **Tidestone Spire**, a kilometer-tall tower of aerogel and lunar regolith that glows faintly in the sunlight. Inside, the rotating **Lunar Senate** debates issues affecting the 4.2 million citizens living in Selenograd and her sister colonies. Each dome district sends representatives chosen from *syndicates* — corporations, cooperatives, and kibbutz-like collectives alike.
#
# ## 💡 Cultural & Economic Power
#
# - **Currency:** The *Helion Credit* (HX), pegged to helium-3 fusion fuel exports.
# - **Notable Industries:** Quantum computing, low-gravity biotech, Helium-3 mining, and Heliograph Art — a luminous form of expression using the unique contrast of lunar light and shadow.
# - **Population:** A mosaic of Terran, Martian, and even a growing population of *Luna-born* people who have never set foot on Earth.
#
# ## 🌗 Quirks of Lunar Life
#
# - Residents celebrate the **"Two Week Holiday"** once a year, when the lunar day and night equalize, and sunlight pours through specially designed sky-prisms, casting rainbow geometries across the city.
# - Citizens speak a creole called **Lunari**, blended from English, Mandarin, Russian, Portuguese, and Swahili.
# - The traditional greeting is to offer a pinch of regolith — symbolizing shared dust, shared origin.
#
# ## ✨ The Slogan of the City
#
# > *"From dust, we rise. From silence, we sing."*
#
# ---
#
# Shall I write a short story set in Selenograd Prime, or perhaps detail another capital — say, on Mars, Europa, or a brand-new world? 🚀

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'NUST ID.png', 'type': 'image/png', 'size': 1044366, 'content': <memory at 0x00000210895FF400>, 'last_modified': datetime.datetime(2024, 11, 13, 15, 31, 40, 476000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# # Islamabad: The Capital of Tomorrow
#
# Nestled against the foothills of the Margalla Hills, **Islamabad** rises like a city plucked from the dreams of visionaries—a planned metropolis where the geometry of grids meets the organic curves of ancient mountains. As the capital of Pakistan, it serves as the political heart of the nation and, increasingly, a hub for science and innovation.
#
# ## The City of Planned Perfection
#
# Founded in the 1960s and master-planned by Greek architect **Constantinos Apostolou Doxiadis**, Islamabad was designed as a city of the future. Its sectors spread outward in neat, numbered quadrants, each one a self-contained neighborhood of schools, parks, mosques, and commercial centers. From above, the city resembles a vast circuit board—streets radiating like traces on a silicon wafer, feeding data and people to the central processors of governance and learning.
#
# ## The Educational Nexus
#
# Within this carefully ordered capital lies the **National University of Sciences & Technology (NUST)**, a beacon of technological advancement. Its campus—particularly the **SEECS (School of Electrical Engineering and Computer Science)**—functions as a neural network of innovation, where the next generation of Pakistani scientists, engineers, and AI researchers are forged. Students like Hajra Binte Naeem, pursuing advanced studies in artificial intelligence (PhDAI-2K23), represent the city's evolving identity: from a seat of government to a foundry of future thought.
#
# ## Landmarks Between Reality and Reverie
#
# - **Faisal Mosque** — A gleaming desert tent of marble and concrete, its eight-story minarets pierce the sky like four sentinel towers watching over the city.
# - **Pakistan Monument** — Four rising petals of stone, symbolizing the unity of Pakistan's provinces, perched at the edge of the Margallas like a crown.
# - **Daman-e-Koh and Pir Sohawa** — Terraced viewpoints where the city unfolds below like a living map, glowing amber at sunset.
# - **Centaurus Mall** — A trio of towers that house commerce, hospitality, and residence, anchoring Islamabad's modern skyline.
# - **Islamabad Expressway & Srinagar Highway** — Arteries pulsing with traffic, lined with acacia and eucalyptus that whisper in the dry mountain wind.
#
# ## The Climate of Innovation
#
# What makes Islamabad unique among world capitals is its paradoxical nature—it is at once serene and ambitious. Mornings arrive crisp and pine-scented from the Margallas, while evenings hum with the quiet industry of research labs, tech startups, and policy think tanks. The dry climate and clear skies make it an ideal site for satellite ground stations, while its universities feed talent into Pakistan's growing space agency, **SUPARCO**, and its emerging AI initiatives.
#
# ## A Capital in Dialogue With the Future
#
# Islamabad is not just a political capital—it is a laboratory of national identity. In its orderly grid, the past and future converse: the call to prayer echoing over rooftops equipped with solar panels, PhD students debugging code in cafes beside diplomats drafting policy, the Margalla leopards stalking forested ridges as drones map terrain below.
#
# It is, in many ways, the kind of city a science fiction writer imagines when asked to dream up a capital—**a place where statecraft and stargazing share the same address**.

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
