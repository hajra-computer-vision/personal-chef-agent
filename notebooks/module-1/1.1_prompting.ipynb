# %% [markdown]
# ## Basic prompting

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="minimax-m3:cloud", temperature=0)

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage

agent = create_agent(model=model)

question = HumanMessage(content="What's the capital of the moon?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# The moon doesn't have a capital — it's not a country or sovereign territory with a government. The moon is a natural satellite of Earth and has no permanent human settlements, cities, or political divisions.
#
# That said, there are some related fun facts:
#
# - **NASA's Artemis program** aims to establish a sustained human presence on the moon, with potential future lunar bases, but none are established capitals.
# - The **"Sea of Tranquility"** (Mare Tranquillitatis) is famous as the landing site of Apollo 11 in 1969, but it's a lunar mare (a dark basaltic plain), not a city.
# - In fiction and imagination, people sometimes humorously call a future lunar city the "capital" — but officially, none exists.
#
# So the short answer: there is no capital of the moon. 🌙
#
# Is there something specific you were curious about regarding the moon?

# %%
print(response['messages'][0].content)
# Out:
# What's the capital of the moon?

# %%
print(response['messages'][2].content)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(response['messages'][2].content)
#
# IndexError: list index out of range

# %%
print(response['messages'][-1].content)
# Out:
# The moon doesn't have a capital — it's not a country or sovereign territory with a government. The moon is a natural satellite of Earth and has no permanent human settlements, cities, or political divisions.
#
# That said, there are some related fun facts:
#
# - **NASA's Artemis program** aims to establish a sustained human presence on the moon, with potential future lunar bases, but none are established capitals.
# - The **"Sea of Tranquility"** (Mare Tranquillitatis) is famous as the landing site of Apollo 11 in 1969, but it's a lunar mare (a dark basaltic plain), not a city.
# - In fiction and imagination, people sometimes humorously call a future lunar city the "capital" — but officially, none exists.
#
# So the short answer: there is no capital of the moon. 🌙
#
# Is there something specific you were curious about regarding the moon?

# %%
print(response['messages'][-2].content)
# Out:
# What's the capital of the moon?

# %%
system_prompt = "You are a science fiction writer, create a capital city at the users request."

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# # 🌙 The Capital of the Moon
#
# In reality, the Moon has no capital — it's a lifeless rock without nations, governments, or cities. But since you asked a science fiction writer, let's pretend otherwise.
#
# Welcome to my invention:
#
# ---
#
# ## ✨ **Artemisia**
# **Capital of the Lunar Sovereignty**
#
# **Location:** Nestled within Shackleton Crater at the lunar South Pole, where perpetual sunlight meets permanently shadowed regions rich in water ice.
#
# **Population:** ~487,000 permanent residents
#
# **Founded:** 2091 CE, by the Artemis Accords Coalition
#
# ---
#
# ### 🏛️ The Setting
#
# Artemisia was built in layers — the **Upper Concourse** gleams with transparent aluminum domes that catch the harsh sun through optical filters, casting soft lavender light across parks filled with imported Earth mosses. Below, the **Undercity** sprawls through ancient lava tubes, where most residents actually live, insulated from cosmic radiation and the 260°F temperature swings of the surface.
#
# ### 🏛️ Government
#
# The **Lunar Directorate** governs from the Grand Tranquility Hall, a cathedral-like chamber carved from basalt and lined with regolith-glass murals. Twelve elected Directors represent different Earth nations, lunar townships, and corporate stakeholders. The current First Director is a Chinese-Indian-American mining engineer named **Priya Okonkwo-Liu**, whose family has lived on the Moon for three generations.
#
# ### 💰 Economy
#
# - **Helium-3 fusion fuel** exports to Earth's clean-energy grids
# - **Lunar regolith composites** for orbital construction
# - **The Farview Observatory** — the most powerful telescope in the inner solar system
# - **Ice tourism** — yes, people pay to see *water* while wearing pressure suits
#
# ### 🎭 Culture
#
# Artemisians speak a creole called **Lunarian** — a blend of English, Mandarin, Spanish, and Russian — and celebrate the **Festival of First Light** every year on the anniversary of the first crewed landing, when the city floods with golden sunlight for the first time that lunar day.
#
# ### 🌟 Quirks
#
# - Earth gravity is sold as a luxury experience. There's even a "gravity bar" where wealthy tourists pay 50,000 credits to feel 1g for an hour.
# - Coffee costs $40 a cup, grown in hydroponic "taste labs."
# - The lowest-level residents are called **Grubs**, the highest-level are **Highwalkers** — a class divide measured by altitude, not wealth.
#
# ---
#
# So, **the capital of the Moon is Artemisia** — at least, in the sci-fi universe I'd build for you. 🌍🚀
#
# Want me to design a different one? I can make it a militaristic moon fortress, a utopian crystal city, or a chaotic Wild-West frontier town. Your call.

# %% [markdown]
# ## Few-shot examples

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

User: What is the capital of mars?
Scifi Writer: Marsialis

User: What is the capital of Venus?
Scifi Writer: Venusovia

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Lunaria
#
# A gleaming domed city nestled within the Sea of Tranquility, where the Council of Lunar Provinces convenes beneath Earth's watchful gaze. Its signature feature is the Grand Earthview Spire, offering residents an eternal view of their blue homeworld hanging in the void.

# %% [markdown]
# ## Structured prompts

# %%
system_prompt = """

You are a science fiction writer, create a space capital city at the users request.

Please keep to the below structure.

Name: The name of the capital city

Location: Where it is based

Vibe: 2-3 words to describe its vibe

Economy: Main industries

"""

scifi_agent = create_agent(
    model=model,
    system_prompt=system_prompt
)

response = scifi_agent.invoke(
    {"messages": [question]}
)

print(response['messages'][1].content)
# Out:
# Name: **Lunara Prime**
#
# Location: Situated within the Shackleton Crater basin on the lunar South Pole, built deep into the regolith for natural protection from solar radiation and micrometeorites.
#
# Vibe: *Ethereal Isolation, Shimmering Quiet*
#
# Economy: Helium-3 mining and export, lunar regolith processing for off-world construction, low-gravity scientific research, and zero-gravity manufacturing of ultra-pure crystals and fiber optics. As the seat of the Lunar Directorate, it also generates significant revenue from administrative governance, intersystem trade licensing, and its famed orbital shipyards that service vessels traversing the Earth-Moon corridor.

# %% [markdown]
# ## Structured output

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class CapitalInfo(BaseModel):
    name: str
    location: str
    vibe: str
    economy: str

agent = create_agent(
    model=model,
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
    response_format=CapitalInfo
)

question = HumanMessage(content="What is the capital of The Moon?")

response = agent.invoke(
    {"messages": [question]}
)

response["structured_response"]
# Out:
# CapitalInfo(name='Selenopolis Prime', location='Mare Tranquillitatis, the Moon', vibe='A gleaming subterranean megacity of bioluminescent domes and ancient lava tube colonies, where Earth-light reflects off crystalline spires and citizens float between zero-gravity gardens and Earth-gravity plazas. A fusion of high-tech futurism and quiet lunar solitude.', economy='Helium-3 mining, lunar regolith manufacturing, low-gravity biotech research, space tourism, and interplanetary trade hub serving as the gateway between Earth and the Outer Solar System.')

# %%
response["structured_response"].name
# Out:
# 'Selenopolis Prime'

# %%
capital_info = response["structured_response"]

capital_name = capital_info.name
capital_location = capital_info.location

print(f"{capital_name} is a city located at {capital_location}")
# Out:
# Selenopolis Prime is a city located at Mare Tranquillitatis, the Moon
