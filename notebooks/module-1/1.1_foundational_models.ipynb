# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Initialising and invoking a model

# %%
#replace OpenAI model with Ollama model
from langchain_ollama import ChatOllama

model = ChatOllama(model="minimax-m3:cloud", temperature=0)

# %%
#from langchain.chat_models import init_chat_model

#model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='The Moon doesn\'t have a capital, as it\'s not a country or a sovereign nation! 🌍🌕\n\nHowever, the Moon does have some interesting "notable" features and locations worth mentioning:\n\n- **Sea of Tranquility (Mare Tranquillitatis)** — This is where Apollo 11 landed in 1969, making it one of the most historically significant spots on the lunar surface.\n- **South Pole-Aitken Basin** — One of the largest known impact craters in the solar system.\n- **Mons Huygens** — The Moon\'s tallest mountain, located in the Montes Apenninus range, standing about 5.5 km (3.4 miles) high.\n\nIf you\'re looking for a fun, lighthearted answer, you could jokingly say **"Luna City"** or **"Tranquility Base"** 🚀\n\nIs there something specific about the Moon you\'d like to learn more about? 🌑', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T09:39:35.057040048Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3433677642, 'load_duration': None, 'prompt_eval_count': 183, 'prompt_eval_duration': None, 'eval_count': 251, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03d70-658e-73e1-a4d5-781b7461f5ee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 183, 'output_tokens': 251, 'total_tokens': 434})

# %%
print(response.content)
# Out:
# The Moon doesn't have a capital, as it's not a country or a sovereign nation! 🌍🌕
#
# However, the Moon does have some interesting "notable" features and locations worth mentioning:
#
# - **Sea of Tranquility (Mare Tranquillitatis)** — This is where Apollo 11 landed in 1969, making it one of the most historically significant spots on the lunar surface.
# - **South Pole-Aitken Basin** — One of the largest known impact craters in the solar system.
# - **Mons Huygens** — The Moon's tallest mountain, located in the Montes Apenninus range, standing about 5.5 km (3.4 miles) high.
#
# If you're looking for a fun, lighthearted answer, you could jokingly say **"Luna City"** or **"Tranquility Base"** 🚀
#
# Is there something specific about the Moon you'd like to learn more about? 🌑

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'created_at': '2026-08-26T09:39:35.057040048Z',
#  'done': True,
#  'done_reason': 'stop',
#  'eval_count': 251,
#  'eval_duration': None,
#  'load_duration': None,
#  'logprobs': None,
#  'model': 'minimax-m3',
#  'model_name': 'minimax-m3',
#  'model_provider': 'ollama',
#  'prompt_eval_count': 183,
#  'prompt_eval_duration': None,
#  'total_duration': 3433677642}

# %% [markdown]
# ## Customising your Model

# %%
model = ChatOllama(
    model="minimax-m3:cloud",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# Moon doesn't have a capital! Since it's not a sovereign nation or politically organized territory, there's no official capital city.
#
# That said, here are some fun related facts:
#
# - **No permanent inhabitants** — The Moon has no cities, governments, or residents (yet). It's governed only by international treaties like the **Outer Space Treaty (1967)**, which says no country can claim ownership of celestial bodies.
# - **Proposed lunar cities** — NASA has proposed concepts like **Shackleton Base** near the Moon's south pole as a future Artemis program outpost, but nothing has been built yet.
# - **Fictional capitals** — In popular culture, the Moon has been given various imaginary capitals, like **Luna City** in *The Jetsons* or **Tycho City** in some sci-fi works.
#
# So for now, the Moon remains a capital-free zone! 🌕

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = ChatOllama(model="minimax-m2.1:cloud")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[12], line 3
#       1 model = ChatOllama(model="minimax-m2.1:cloud")
#       2
# ----> 3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1200, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1193 def _generate(
#    1194     self,
#    1195     messages: list[BaseMessage],
#    (...)   1198     **kwargs: Any,
#    1199 ) -> ChatResult:
# -> 1200     final_chunk = self._chat_stream_with_aggregation(
#    1201         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1202     )
#    1203     generation_info = final_chunk.generation_info
#    1204     chat_generation = ChatGeneration(
#    1205         message=AIMessage(
#    1206             content=final_chunk.text,
#    (...)   1213         generation_info=generation_info,
#    1214     )
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1135, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#    1126 def _chat_stream_with_aggregation(
#    1127     self,
#    1128     messages: list[BaseMessage],
#    (...)   1132     **kwargs: Any,
#    1133 ) -> ChatGenerationChunk:
#    1134     final_chunk = None
# -> 1135     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#    1136         if final_chunk is None:
#    1137             final_chunk = chunk
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1224, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1217 def _iterate_over_stream(
#    1218     self,
#    1219     messages: list[BaseMessage],
#    1220     stop: list[str] | None = None,
#    1221     **kwargs: Any,
#    1222 ) -> Iterator[ChatGenerationChunk]:
#    1223     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1224     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1225         if not isinstance(stream_resp, str):
#    1226             content = (
#    1227                 stream_resp["message"]["content"]
#    1228                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1229                 else ""
#    1230             )
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\langchain_ollama\chat_models.py:1122, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#    1119 chat_params = self._chat_params(messages, stop, **kwargs)
#    1121 if chat_params["stream"]:
# -> 1122     yield from self._client.chat(**chat_params)
#    1123 else:
#    1124     yield self._client.chat(**chat_params)
#
# File ~\Langchain-projects\lca-lc-foundations\.venv\Lib\site-packages\ollama\_client.py:189, in Client._request.<locals>.inner()
#     187 except httpx.HTTPStatusError as e:
#     188   e.response.read()
# --> 189   raise ResponseError(e.response.text, e.response.status_code) from None
#     191 for line in r.iter_lines():
#     192   part = json.loads(line)
#
# ResponseError: minimax-m2.1 was retired at 2026-07-15 00:00:00 -0700 PDT (ref: c7bde86d-c1ca-44a3-b847-4906a056ab9e) (status code: 410)

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='25565cb5-119a-41d8-a4a7-9e77f50f5927'),
#               AIMessage(content='doesn\'t have a capital city, since it\'s a natural satellite (a celestial body orbiting Earth) and not a country, nation, or sovereign state. It has no permanent human inhabitants, governments, or cities — though astronauts from various space agencies have visited it.\n\nIf you\'re thinking about a "lunar capital" in a science-fiction context, some popular fictional versions include:\n\n- **Luna City** (from Robert Heinlein\'s *The Moon Is a Harsh Mistress*)\n- **Tycho City** or **Endymion** (in various sci-fi universes)\n- **Moonbase Alpha** (from *Space: 1999*)\n\nWere you curious about the Moon for astronomy reasons, or perhaps thinking of a fictional setting? I\'d be happy to help either way!', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T09:44:51.789955925Z', 'done': True, 'done_reason': 'stop', 'total_duration': 4126541486, 'load_duration': None, 'prompt_eval_count': 183, 'prompt_eval_duration': None, 'eval_count': 213, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03d75-392c-72d3-9665-818a20d75f48-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 183, 'output_tokens': 213, 'total_tokens': 396})]}

# %%
print(response['messages'][-1].content)
# Out:
# doesn't have a capital city, since it's a natural satellite (a celestial body orbiting Earth) and not a country, nation, or sovereign state. It has no permanent human inhabitants, governments, or cities — though astronauts from various space agencies have visited it.
#
# If you're thinking about a "lunar capital" in a science-fiction context, some popular fictional versions include:
#
# - **Luna City** (from Robert Heinlein's *The Moon Is a Harsh Mistress*)
# - **Tycho City** or **Endymion** (in various sci-fi universes)
# - **Moonbase Alpha** (from *Space: 1999*)
#
# Were you curious about the Moon for astronomy reasons, or perhaps thinking of a fictional setting? I'd be happy to help either way!

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='180038d7-5461-47de-997a-8137dcf37be2'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='0f1080ae-67c9-46fd-a0ba-0b84665c8aa8', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='543757bf-7e51-4e02-b5ea-c554dea14389'),
#               AIMessage(content='Luna City is the administrative capital of the Moon, located in the Sea of Tranquility. It has a population of about 2 million and serves as the hub of lunar governance, science, and tourism.', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T09:47:07.274042855Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1733003817, 'load_duration': None, 'prompt_eval_count': 211, 'prompt_eval_duration': None, 'eval_count': 45, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03d77-5219-7583-9e6d-0fa092b573bf-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 211, 'output_tokens': 45, 'total_tokens': 256})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# There is no actual capital of the Moon, because the Moon is not a sovereign nation and has no permanent government or capital city. The Outer Space Treaty of 1967, signed by most countries including the U.S., explicitly forbids any nation from claiming sovereignty over celestial bodies, and as of now, no independent lunar state exists.
#
# That said, "Luna City" is a well-known concept in science fiction, so you may be thinking of one of these fictional versions:
#
# **Fictional Luna Cities:**
#
# - **Robert Heinlein's Luna City** — Featured prominently in *The Moon Is a Harsh Mistress* (1966). In this novel, Luna City is a penal colony that grew into a self-governing society and eventually revolts against Earth, declaring independence. Heinlein also referenced a similar Luna City in earlier stories.
#
# - **Arthur C. Clarke's lunar settlements** — Featured in works like *2001: A Space Odyssey* and *The Wind from the Sun*, with moonbases run by various nations and corporations.
#
# - **Isaac Asimov's Foundation series** — Mentions lunar cities as part of humanity's far-future civilization.
#
# - **Various video games and films** — Games like *Destiny 2*, *Mass Effect*, and films like *Iron Sky* depict their own versions of lunar cities.
#
# **Real-World Lunar Plans:**
#
# - **NASA's Artemis program** aims to establish a sustained human presence on the Moon, with a base camp near the lunar south pole, but it won't be a "capital."
# - Concepts like the **Lunar Village** (proposed by ESA) imagine international cooperation rather than a single sovereign capital.
#
# If you were thinking of a specific fictional work, I'd be happy to discuss that in more detail!
