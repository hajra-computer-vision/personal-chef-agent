# %% [markdown]
# ## Without web search

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="minimax-m3:cloud", temperature=0)

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="How up to date is your training knowledge?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
print(response['messages'][-1].content)
# Out:
# knowledge has a cutoff of January 2026. This means I have information about events, developments, and topics up to that point, but I don't have knowledge of anything that happened after January 2026.
#
# For anything more recent, I'd recommend checking current sources, as my information may not reflect the latest updates or developments.

# %% [markdown]
# ## Add web search tool

# %%
from langchain.tools import tool
from typing import Dict, Any
from tavily import TavilyClient

tavily_client = TavilyClient()

@tool
def web_search(query: str) -> Dict[str, Any]:

    """Search the web for information"""

    return tavily_client.search(query)

web_search.invoke("Who is the current mayor of San Francisco?")
# Out:
# {'query': 'Who is the current mayor of San Francisco?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/Daniel_Lurie',
#    'title': 'Daniel Lurie',
#    'content': 'Daniel Lawrence Lurie (born February 4, 1977) is an American politician and philanthropist who is the 46th and incumbent mayor of San Francisco, serving since 2025. He was elected in 2024, defeating then-incumbent London Breed. He is the founder and former CEO of Tipping Point Community.\n\n## Early life\n\n[edit source] [...] | Lurie in 2024 |\n| 46th Mayor of San Francisco |\n| Incumbent |\n| Assumed office  January 8, 2025 |\n| Preceded by | London Breed |\n|  |\n| Personal details |\n| Born | Daniel Lawrence Lurie  (1977-02-04) February 4, 1977 (age 49)  San Francisco, California, U.S. |\n| Party | Democratic "Democratic Party (United States)") |\n| Spouse | Becca Prowda   \u200b (m. 2006)\u200b |\n| Children | 2 |\n| Relatives | Mimi Haas (mother) Peter E. Haas (stepfather) | [...] 30. ↑ "Daniel Lurie sworn in as 46th Mayor of San Francisco". CBS News San Francisco. January 8, 2025. Archived from the original on January 9, 2025. Retrieved January 8, 2025.\n31. ↑ Sharon Song (December 3, 2024). "San Francisco Mayor-elect Daniel Lurie plans to take $1 annual salary". Fox 2 KTVU.\n32. ↑ How\'s Lurie doing as mayor? Our new poll on the state of S.F. had stunning results Archived August 28, 2025, at the Wayback Machine. July 21, 2025. Danielle Echeverria',
#    'score': 0.9797453,
#    'raw_content': None,
#    'id': '12a1d1-00'},
#   {'url': 'https://ballotpedia.org/Daniel_Lurie',
#    'title': 'Daniel Lurie - Ballotpedia',
#    'content': "#### Sign up to receive Ballotpedia's daily newsletter\n\nEmail \\\n\nFirst Name\n\nPlease complete the Captcha above\n\n#### Ballotpedia on Facebook\n\nShare this page\n\nFollow Ballotpedia\n\n#### Ballotpedia on Twitter\n\nShare this page\n\nFollow Ballotpedia\n\nBallotpedia Logo\nBallotpedia Logo\n\n# Daniel Lurie\n\nSilhouette Placeholder Image.png\n\nReport an officeholder change\n\nDaniel Lurie is the mayor of San Francisco, California. He assumed office on January 8, 2025. His current term ends on January 8, 2029.",
#    'score': 0.9659639,
#    'raw_content': None,
#    'id': '33b562-01'},
#   {'url': 'https://en.wikipedia.org/wiki/Mayor_of_San_Francisco',
#    'title': 'Mayor of San Francisco - Wikipedia',
#    'content': '| Seal of San Francisco |\n| Flag of San Francisco |\n| Incumbent Daniel Lurie since January 8, 2025 |\n| Government of San Francisco |\n| Style "Style (form of address)") | His Honor   Mr. Mayor |\n| Residence | No official residence |\n| Term length | Four years, renewable once |\n| Inaugural holder | John W. Geary |\n| Formation | 1850 |\n| Salary | $1 |\n| Website | Office of the Mayor | [...] There have been 45 individuals who have served as mayor in San Francisco since 1850, when California became a state following the American Conquest of California. Prior to the conquest, Californios served as Mayor of San Francisco during the Spanish and Mexican eras since 1779.\n\nThe current mayor is Democrat Daniel Lurie.\n\n## Elections\n\n[edit]\n\nMain articles: 1979 San Francisco mayoral election, 1995, 1999, 2003, 2007, 2011, 2015, 2018, 2019, and 2024 [...] ## Salary and benefits\n\n[edit]\n\nAs of 2024, the mayor is paid an annual salary of $364,582, the highest mayoral salary in the United States. Nine city public employees earned higher salaries than the mayor, including the chief investment officer and the managing director of the San Francisco Employees\' Retirement System, who oversee the city\'s pension plan. Current mayor Daniel Lurie decided to return all but $1 of his annual salary back to San Francisco.',
#    'score': 0.9549004,
#    'raw_content': None,
#    'id': '82d705-02'},
#   {'url': 'https://www.sf.gov/departments--office-mayor',
#    'title': 'Office of the Mayor | SF.gov',
#    'content': "Visit us\n\nCity HallPermit Center\n\nFind contacts\n\nAgency\n\n# Office of the Mayor\n\nDaniel Lurie is the 46th Mayor of the City and County of San Francisco.\n\nImage 2: Image of Mayor Daniel Lurie\n\n## Mayor Daniel Lurie\n\nWe are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.Read about Mayor Lurie's priorities [...] ## About\n\nWe are here to provide exceptional core city services that enable every San Franciscan to live safe, healthy and productive lives.\n\nLearn more about us\n\n### Office of the Mayor's newsletter\n\nJoin the mailing list for our newsletter.Sign up for our newsletter\n\n### Mayor\n\nDaniel Lurie is the 46th Mayor of the City and County of San Francisco.\n\nImage 3: Mayor Daniel LurieDaniel Lurie Mayor\n\n## Contact information\n\n### Address\n\nCity Hall 1 Dr Carlton B. Goodlett Place\n\nRoom 200 [...] July 04\n\nJuly 04\n\nEvent\n\nFourth of July fireworks on Golden Gate Bridge\n\nSaturday, July 04, 2026\n\n9:30 pm\n\n## News\n\nSee all news\n\nMayor Lurie Strengthens Good Neighbor Policy to Ensure Safer, Cleaner Streets Around City-Funded Health Facilities August 19, 2026Mayor Lurie's Statement on San Francisco Winning 2027 WNBA All-Star Game August 18, 2026Mayor Lurie Launches Outreach Campaign to Help San Franciscans Keep Critical Healthcare, Food Assistance August 17, 2026",
#    'score': 0.94509614,
#    'raw_content': None,
#    'id': '68383d-03'},
#   {'url': 'https://www.facebook.com/NancyPelosi/posts/congratulations-daniel-lurie-46th-mayor-of-san-francisco-an-innovative-empathic-/1145803600245781',
#    'title': 'Congratulations, Daniel Lurie, 46th Mayor of San Francisco - Facebook',
#    'content': "## Speaker Emerita Nancy Pelosi's post\n\n### Speaker Emerita Nancy Pelosi\n\n8 January 2025  ·\n\nCongratulations, Daniel Lurie, 46th Mayor of San Francisco — an innovative, empathic leader elected with a call to service, change and accountability.\n\nI look forward to working with Mayor Lurie toward a thriving San Francisco for all! [...] stop-color='%2302ADFC'/%3E%3Cstop offset='.5' stop-color='%230866FF'/%3E%3Cstop offset='1' stop-color='%232B7EFF'/%3E%3C/linearGradient%3E%3C/defs%3E%3C/svg%3E) [...] stop-color='%23FFF287'/%3E%3Cstop offset='1' stop-color='%23F68628' stop-opacity='.3'/%3E%3C/linearGradient%3E%3ClinearGradient id='paint15_linear_15251_63610' x1='7.9727' y1='12.4766' x2='18.4483' y2='13.8876' gradientUnits='userSpaceOnUse'%3E%3Cstop offset='.0835' stop-color='%23FFF287'/%3E%3Cstop offset='1' stop-color='%23F68628'/%3E%3C/linearGradient%3E%3CclipPath id='clip0_15251_63610'%3E%3Cpath fill='%23fff'",
#    'score': 0.9238675,
#    'raw_content': None,
#    'id': '09d4a0-04'}],
#  'response_time': 1.33,
#  'request_id': 'af39d603-0d1a-4d64-87c6-5b12710bc3fb'}

# %%
agent = create_agent(
    model=model,
    tools=[web_search]
)

question = HumanMessage(content="When will Eid milad un nabi be celebrated in pakistan rawalipindi?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='When will Eid milad un nabi be celebrated in pakistan rawalipindi?', additional_kwargs={}, response_metadata={}, id='4b7e8253-48bf-449f-be95-354e4874a793'),
#  AIMessage(content="I don't have real-time information, but I can search for the expected date of Eid Milad un Nabi in Pakistan for the current year.", additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T10:43:50.0930971Z', 'done': True, 'done_reason': 'tool_calls', 'total_duration': 2915752120, 'load_duration': None, 'prompt_eval_count': 417, 'prompt_eval_duration': None, 'eval_count': 168, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03dab-3b52-72f1-9520-0a99fd0b0858-0', tool_calls=[{'name': 'web_search', 'args': {'query': 'Eid Milad un Nabi 2025 date Pakistan Rawalpindi'}, 'id': '61128bcd-e8c1-4290-bcc5-7f712814134f', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 417, 'output_tokens': 168, 'total_tokens': 585}),
#  ToolMessage(content='{"query": "Eid Milad un Nabi 2025 date Pakistan Rawalpindi", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://rcf.org.pk/NewsAndEvents/EventDetail/12-rabi-ul-awal-date-and-eid-milad-un-nabi", "title": "EventDetail - Renal Care Foundation", "content": "Every year Muslims all over the world look forward to the date of Eid Milad un Nabi. Pakistan will observe 12 Rabi ul Awal 2025 on 6th September 2025, subject to the visibility of the moonThis is a national holiday on which Muslims can attend processions, masjid programs, and spend time in the memory of the Prophet.\\n\\n### Why Muslims Celebrate Rabi al-Awal [...] Loading...\\n\\nMonday - Saturday\\n\\n12 Rabi ul Awal Date & Eid Milad un-Nabi\\n\\n#### 12 Rabi ul Awal Date & Eid Milad un-Nabi 2025 in Pakistan\\n\\n##### Description\\n\\nLearn about 12 Rabi ul Awal, the birth of Prophet Muhammad (S.A.W.), Eid Milad un Nabi celebrations, and why this blessed month holds great importance.\\n\\n### About Rabi ul Awal [...] In 2025, 12 Rabi ul Awal will be on 6th September 2025, depending on the sighting of the moon.\\n\\nQ3: What are some of the ways in which Muslims celebrate Eid Milad un Nabi?\\n\\nMuslims commemorate it by participating in meetings, reciting the Quran, listening to naats, conducting processions, adorning their homes and mosques and taking care of the poor.\\n\\nQuestion 4: Is Eid Milad un Nabi a Pakistani holiday?", "score": 0.8980626, "raw_content": null, "id": "244fd6-00"}, {"url": "https://www.officeholidays.com/holidays/pakistan/mawlid", "title": "Eid Milad-un-Nabi in Pakistan in 2026 | Office Holidays", "content": "| Eid Milad-un-Nabi |\\n| Dates of Eid Milad-un-Nabi in Pakistan |\\n| 2027 Pakistan Sun, Aug 15 National Holiday  2026 Pakistan Tue, Aug 25 National Holiday  2025 Sep 5, Sep 6  PakistanSat, Sep 6National Holiday  SindhFri, Sep 5Regional Holiday  2024 Pakistan Tue, Sep 17 National Holiday  2023 Sep 29, Sep 30, Oct 1  PakistanSun, Oct 1National Holiday (additional day)  PakistanSat, Sep 30National Holiday (additional day)  PakistanFri, Sep 29National Holiday |\\n| Summary | [...] | Summary |\\n| Celebrated by Muslims on the twelfth day of the month of Rabiulawal, the third month of the Muslim calendar |\\n| Eid Milad-un-Nabi in other countries |\\n| Eid Milad-un-Nabi internationally | [...] The Sunni and Shia branches of Islam have different ways of marking the day. The Shia community believes that on 12 Rabiulawal, the Prophet Muhammad chose Hazrat Ali as his successor. The Sunni community holds prayers throughout the month and they do not practice mourning on this day.", "score": 0.83549726, "raw_content": null, "id": "53c5a1-01"}, {"url": "https://www.timeanddate.com/holidays/pakistan/eid-milad-un-nabi", "title": "Eid Milad un-Nabi 2026 in Pakistan", "content": "| 2020 | Fri | Oct 30 | Eid Milad un-Nabi | Public Holiday |\\n| 2021 | Tue | Oct 19 | Eid Milad un-Nabi | Public Holiday |\\n| 2022 | Sun | Oct 9 | Eid Milad un-Nabi | Public Holiday |\\n| 2023 | Fri | Sep 29 | Eid Milad un-Nabi | Public Holiday |\\n| 2024 | Tue | Sep 17 | Eid Milad un-Nabi | Public Holiday |\\n| 2025 | Sat | Sep 6 | Eid Milad un-Nabi | Public Holiday |\\n| 2026 | Wed | Aug 26 | Eid Milad un-Nabi | Public Holiday | [...] | Next year: | To be announced |\\n| Last year: | Sat, Sep 6, 2025 |\\n| Type: | Public Holiday |\\n\\nList of dates for other years\\n\\nUpcoming holidays in Pakistan\\n\\nHolidays in Pakistan 2026\\n\\nHolidays in Pakistan 2027 [...] Eid Milad-un-Nabi, also known as the Prophet Muhammad’s birthday, is a public holiday in Pakistan. Sunni Muslims observe Milad-un-Nabi on 12 Rabi-ul-Awwal (third month of the Islamic calendar) while Shia Muslims observe it on 17 Rabi-ul-Awwal, coinciding with the birthdate of their sixth Imam Jafar-al-Sadiq.\\n\\n## Is Eid Milad un-Nabi a Public Holiday?\\n\\nEid Milad un-Nabi is a public holiday. It is a day off for the general population, and schools and most  ...
#  AIMessage(content='# Eid Milad un Nabi in Pakistan (including Rawalpindi)\n\nEid Milad un Nabi is observed nationwide in Pakistan, so the date in **Rawalpindi** is the same as the rest of the country.\n\n## Upcoming Dates\n\n| Year | Date | Day |\n|------|------|-----|\n| **2026** | **26 August 2026** (12 Rabi ul Awal 1448 A.H.) | Wednesday |\n| 2025 | 6 September 2025 | Saturday (passed) |\n\n## Important Note\nThe exact date is **subject to the sighting of the moon** by Pakistani religious authorities (the Central Ruet-e-Hilal Committee) on the eve of 12 Rabi ul Awal. Sometimes the holiday may be observed on a neighboring day if the moon is sighted a day earlier or later.\n\n## Celebrations in Rawalpindi\nOn this day, you can expect:\n- 🎉 Public holiday — government offices, schools, and most businesses closed\n- 🕌 Special prayers and gatherings at mosques, including the famous **Raja Bazaar** and other major mosques\n- 📿 Processions (jaloos) through the city streets with naat recitations\n- 🏠 Homes and mosques decorated with lights and green flags\n- 🍬 Distribution of sweets and food to family, neighbors, and the poor\n\nFor the most accurate and confirmed date closer to the time, keep an eye on announcements from the **Central Ruet-e-Hilal Committee** and the **Government of Pakistan Cabinet Division**.', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T10:43:58.664104653Z', 'done': True, 'done_reason': 'stop', 'total_duration': 5610095510, 'load_duration': None, 'prompt_eval_count': 2446, 'prompt_eval_duration': None, 'eval_count': 376, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03dab-5248-7601-bada-f632b55cfccc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 2446, 'output_tokens': 376, 'total_tokens': 2822})]

# %% [markdown]
# trace: https://smith.langchain.com/public/59432173-0dd6-49e8-9964-b16be6048426/r

# %%
print(response['messages'][-1].content)
# Out:
# # Eid Milad un Nabi in Pakistan (including Rawalpindi)
#
# Eid Milad un Nabi is observed nationwide in Pakistan, so the date in **Rawalpindi** is the same as the rest of the country.
#
# ## Upcoming Dates
#
# | Year | Date | Day |
# |------|------|-----|
# | **2026** | **26 August 2026** (12 Rabi ul Awal 1448 A.H.) | Wednesday |
# | 2025 | 6 September 2025 | Saturday (passed) |
#
# ## Important Note
# The exact date is **subject to the sighting of the moon** by Pakistani religious authorities (the Central Ruet-e-Hilal Committee) on the eve of 12 Rabi ul Awal. Sometimes the holiday may be observed on a neighboring day if the moon is sighted a day earlier or later.
#
# ## Celebrations in Rawalpindi
# On this day, you can expect:
# - 🎉 Public holiday — government offices, schools, and most businesses closed
# - 🕌 Special prayers and gatherings at mosques, including the famous **Raja Bazaar** and other major mosques
# - 📿 Processions (jaloos) through the city streets with naat recitations
# - 🏠 Homes and mosques decorated with lights and green flags
# - 🍬 Distribution of sweets and food to family, neighbors, and the poor
#
# For the most accurate and confirmed date closer to the time, keep an eye on announcements from the **Central Ruet-e-Hilal Committee** and the **Government of Pakistan Cabinet Division**.
