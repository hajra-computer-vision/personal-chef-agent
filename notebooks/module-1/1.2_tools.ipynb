# %% [markdown]
# ## Tool definition

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.tools import tool

@tool
def square_root(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root")
def tool1(x: float) -> float:
    """Calculate the square root of a number"""
    return x ** 0.5

# %%
@tool("square_root", description="Calculate the square root of a number")
def tool1(x: float) -> float:
    return x ** 0.5

# %%
tool1.invoke({"x": 467})
# Out:
# 21.61018278497431

# %% [markdown]
# ## Adding to agents

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(model="minimax-m3:cloud", temperature=0)

# %%
from langchain.agents import create_agent

agent = create_agent(
    model=model,
    tools=[tool1],
    system_prompt="You are an arithmetic wizard. Use your tools to calculate the square root and square of any number."
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="What is the square root of 467?")

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# The square root of 467 is approximately **21.6102** (more precisely, 21.61018278497431).

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='What is the square root of 467?', additional_kwargs={}, response_metadata={}, id='3ab4eb43-6538-4fa6-aca4-b6ac6a6b6954'),
#  AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T10:29:02.696824412Z', 'done': True, 'done_reason': 'tool_calls', 'total_duration': 1426939972, 'load_duration': None, 'prompt_eval_count': 425, 'prompt_eval_duration': None, 'eval_count': 45, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03d9d-b51a-7b23-ab44-4c80710c7996-0', tool_calls=[{'name': 'square_root', 'args': {'x': 467}, 'id': 'f98cf3a5-3d23-4d4a-9bd0-9ab1deb8d808', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 425, 'output_tokens': 45, 'total_tokens': 470}),
#  ToolMessage(content='21.61018278497431', name='square_root', id='90780734-a4bc-43c4-94e9-bcab7f4c3b09', tool_call_id='f98cf3a5-3d23-4d4a-9bd0-9ab1deb8d808'),
#  AIMessage(content='The square root of 467 is approximately **21.6102** (more precisely, 21.61018278497431).', additional_kwargs={}, response_metadata={'model': 'minimax-m3', 'created_at': '2026-08-26T10:29:05.077658769Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1959720571, 'load_duration': None, 'prompt_eval_count': 474, 'prompt_eval_duration': None, 'eval_count': 57, 'eval_duration': None, 'logprobs': None, 'model_name': 'minimax-m3', 'model_provider': 'ollama'}, id='lc_run--01a03d9d-bd95-7c12-8397-2ce4b4aebaed-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 474, 'output_tokens': 57, 'total_tokens': 531})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'square_root', 'args': {'x': 467}, 'id': 'f98cf3a5-3d23-4d4a-9bd0-9ab1deb8d808', 'type': 'tool_call'}]
